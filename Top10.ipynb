# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("311_Service_Requests_2020.csv")
# Out:
# /Users/varun/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 0          45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1          45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2          45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3          45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4          45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# ...             ...                     ...                     ...    ...
# 2587311    48536847  12/31/2020 12:00:00 AM  12/31/2020 02:10:48 PM  DOHMH
# 2587312    48537845  12/31/2020 12:00:00 AM  12/31/2020 02:10:13 PM  DOHMH
# 2587313    48536999  12/31/2020 12:00:00 AM  01/06/2021 12:00:01 AM  DOHMH
# 2587314    48538698  12/31/2020 12:00:00 AM  12/31/2020 12:00:01 AM  DOHMH
# 2587315    48543111  12/31/2020 12:00:00 AM  12/31/2020 12:00:01 AM  DOHMH
#
# ...

# %%
data_cu=data[data['Incident Zip']==10027.0]
data_cu
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 305        45278190  01/01/2020 01:10:07 AM  01/01/2020 09:00:02 AM   NYPD
# 542        45281550  01/01/2020 01:52:36 AM  01/01/2020 02:58:35 AM   NYPD
# 553        45281044  01/01/2020 01:54:22 AM  01/01/2020 11:12:27 AM   NYPD
# 614        45289780  01/01/2020 02:04:07 AM  01/01/2020 05:06:45 AM   NYPD
# 693        45287804  01/01/2020 02:18:51 AM  01/01/2020 05:07:33 AM   NYPD
# ...             ...                     ...                     ...    ...
# 2586194    48534154  12/30/2020 07:59:11 PM  01/05/2021 02:19:26 PM    DOT
# 2586950    48535401  12/30/2020 10:43:45 PM  12/30/2020 10:52:58 PM   NYPD
# 2587055    48529353  12/30/2020 11:03:00 PM  12/31/2020 11:08:00 AM    DEP
# 2587073    48533848  12/30/2020 11:09:26 PM  12/31/2020 12:51:56 AM   NYPD
# 2587183    48527925  12/30/2020 11:33:43 PM  12/31/2020 12:34:30 AM   NYPD
#
# ...

# %%
type_com=data_cu['Complaint Type']
type_com
# Out:
# 305             Noise - Commercial
# 542            Noise - Residential
# 553        Noise - Street/Sidewalk
# 614            Noise - Residential
# 693             Noise - Commercial
#                     ...
# 2586194         Sidewalk Condition
# 2586950        Noise - Residential
# 2587055                       Lead
# 2587073        Noise - Residential
# 2587183        Noise - Residential
# Name: Complaint Type, Length: 21470, dtype: object

# %%
ans1=type_com.value_counts().head(10)
ans1
# Out:
# Noise - Residential            3610
# Noise - Street/Sidewalk        3087
# HEAT/HOT WATER                 2138
# Illegal Parking                1118
# Non-Emergency Police Matter     862
# Illegal Fireworks               779
# Noise - Vehicle                 647
# UNSANITARY CONDITION            628
# PLUMBING                        465
# Noise                           443
# Name: Complaint Type, dtype: int64

# %%
top10_type=['Noise - Residential','HEAT/HOT WATER','Noise - Street/Sidewalk','Non-Emergency Police Matter',
            'Illegal Parking','Illegal Fireworks','Noise - Vehicle','Consumer Complaint','Noise','UNSANITARY CONDITION']

ans2=data['Complaint Type'].value_counts().head(20)
ans2
# Out:
# Noise - Residential                    406050
# Noise - Street/Sidewalk                206541
# Illegal Parking                        193721
# HEAT/HOT WATER                         164071
# Blocked Driveway                       116377
# Non-Emergency Police Matter             83914
# Noise - Vehicle                         81074
# Damaged Tree                            73051
# Street Light Condition                  64793
# UNSANITARY CONDITION                    61964
# Street Condition                        52684
# NonCompliance with Phased Reopening     51834
# Water System                            50320
# Illegal Fireworks                       49402
# Noise                                   44912
# Noise - Commercial                      43722
# Missed Collection (All Materials)       40848
# PLUMBING                                37047
# General Construction/Plumbing           35508
# Consumer Complaint                      34931
# Name: Complaint Type, dtype: int64

# %%
number=[163022,83555,73611,71531,75408,19214,27571,24715,21973,20143]

dic={'Complaint Type':['Noise - Residential','HEAT/HOT WATER','Noise - Street/Sidewalk','Non-Emergency Police Matter',
            'Illegal Parking','Illegal Fireworks','Noise - Vehicle','Consumer Complaint','Noise','UNSANITARY CONDITION'],
    'number':[163022,83555,73611,71531,75408,19214,27571,24715,21973,20143]}
top10=pd.DataFrame(dic)
top10

# %%
# Out:
# /Users/zhicezhang/Desktop/Code/Python/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 0          45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1          45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2          45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3          45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4          45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# ...             ...                     ...                     ...    ...
# 1048570    46648401  06/26/2020 01:19:40 PM  07/13/2020 02:02:08 AM    HPD
# 1048571    46650766  06/26/2020 01:19:40 PM  07/13/2020 02:02:09 AM    HPD
# 1048572    46633524  06/26/2020 01:19:41 PM  06/26/2020 01:43:23 PM   NYPD
# 1048573    46636033  06/26/2020 01:20:04 PM  06/26/2020 01:54:39 PM   NYPD
# 1048574    46646603  06/26/2020 01:20:14 PM  06/26/2020 01:49:39 PM   NYPD
#
# ...

# %%
data_cu=data[data['Incident Zip']==10027.0]
data_cu
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 305        45278190  01/01/2020 01:10:07 AM  01/01/2020 09:00:02 AM   NYPD
# 542        45281550  01/01/2020 01:52:36 AM  01/01/2020 02:58:35 AM   NYPD
# 553        45281044  01/01/2020 01:54:22 AM  01/01/2020 11:12:27 AM   NYPD
# 614        45289780  01/01/2020 02:04:07 AM  01/01/2020 05:06:45 AM   NYPD
# 693        45287804  01/01/2020 02:18:51 AM  01/01/2020 05:07:33 AM   NYPD
# ...             ...                     ...                     ...    ...
# 1047326    46645448  06/26/2020 10:34:43 AM  06/26/2020 10:41:54 AM   NYPD
# 1047356    46642063  06/26/2020 10:39:11 AM  06/26/2020 11:05:36 AM   NYPD
# 1047807    46633443  06/26/2020 11:38:02 AM  06/30/2020 12:00:00 AM    DOB
# 1048137    46639719  06/26/2020 12:10:53 PM  06/29/2020 01:06:50 PM    DCA
# 1048460    46637881  06/26/2020 01:01:02 PM  06/26/2020 02:58:24 PM   NYPD
#
# ...

# %%
type_com=data_cu['Complaint Type']
type_com
# Out:
# 305                   Noise - Commercial
# 542                  Noise - Residential
# 553              Noise - Street/Sidewalk
# 614                  Noise - Residential
# 693                   Noise - Commercial
#                        ...
# 1047326      Non-Emergency Police Matter
# 1047356      Non-Emergency Police Matter
# 1047807    General Construction/Plumbing
# 1048137               Consumer Complaint
# 1048460              Noise - Residential
# Name: Complaint Type, Length: 8986, dtype: object

# %%
ans1=type_com.value_counts().head(10)
ans1
# Out:
# Noise - Residential            1786
# HEAT/HOT WATER                 1117
# Noise - Street/Sidewalk         996
# Non-Emergency Police Matter     774
# Illegal Parking                 402
# Illegal Fireworks               310
# Noise - Vehicle                 234
# Consumer Complaint              208
# Noise                           204
# UNSANITARY CONDITION            179
# Name: Complaint Type, dtype: int64

# %%
top10_type=['Noise - Residential','HEAT/HOT WATER','Noise - Street/Sidewalk','Non-Emergency Police Matter',
            'Illegal Parking','Illegal Fireworks','Noise - Vehicle','Consumer Complaint','Noise','UNSANITARY CONDITION']

ans2=data['Complaint Type'].value_counts().head(20)
ans2
# Out:
# Noise - Residential                  163022
# HEAT/HOT WATER                        83555
# Illegal Parking                       75408
# Noise - Street/Sidewalk               73611
# Non-Emergency Police Matter           71531
# Blocked Driveway                      44052
# Street Light Condition                33367
# Street Condition                      28689
# Noise - Vehicle                       27571
# Consumer Complaint                    24715
# Noise                                 21973
# UNSANITARY CONDITION                  20143
# Illegal Fireworks                     19214
# Water System                          18210
# General Construction/Plumbing         16456
# Abandoned Vehicle                     14564
# Noise - Commercial                    14238
# Traffic Signal Condition              13691
# Missed Collection (All Materials)     13667
# PLUMBING                              12917
# Name: Complaint Type, dtype: int64

# %%
number=[163022,83555,73611,71531,75408,19214,27571,24715,21973,20143]

dic={'Complaint Type':['Noise - Residential','HEAT/HOT WATER','Noise - Street/Sidewalk','Non-Emergency Police Matter',
            'Illegal Parking','Illegal Fireworks','Noise - Vehicle','Consumer Complaint','Noise','UNSANITARY CONDITION'],
    'number':[163022,83555,73611,71531,75408,19214,27571,24715,21973,20143]}
top10=pd.DataFrame(dic)
top10
# Out:
#                 Complaint Type  number
# 0          Noise - Residential  163022
# 1               HEAT/HOT WATER   83555
# 2      Noise - Street/Sidewalk   73611
# 3  Non-Emergency Police Matter   71531
# 4              Illegal Parking   75408
# 5            Illegal Fireworks   19214
# 6              Noise - Vehicle   27571
# 7           Consumer Complaint   24715
# 8                        Noise   21973
# 9         UNSANITARY CONDITION   20143
